# %%
from tqdm import tqdm 
from rdkit import Chem  
from rdkit.Chem import AllChem
from rdkit import RDLogger
lg = RDLogger.logger()
lg.setLevel(RDLogger.CRITICAL)

#smiles = [a.split("\t")[0] for a in open("gdb11_size09.smi", "r").read().split("\n")][:1024]
smiles = [a.split("\t")[0] for a in open("gdb11_size05.smi", "r").read().split("\n")]

smiles_9 = []

num_hs = []
for smile in tqdm(smiles):
  atoms = [a for a in list(smile.upper()) if a == "C" or a == "N" or a == "O" or a == "F"]
  if len(atoms) != 5: continue 
  smiles_9.append(smile)
  b = Chem.MolFromSmiles(smile)
  b = Chem.AddHs(b) 
  atoms = [atom.GetSymbol() for atom in b.GetAtoms()]
  num_hs.append( len([a for a in atoms if a.upper() == "H"]))
# Out:
# 100%|██████████| 353/353 [00:00<00:00, 4754.67it/s]

# %%
import numpy as np 
num_hs = np.array(num_hs)
sorted_smiles = np.array(smiles_9)[np.argsort(num_hs)].tolist()
print(sorted_smiles)
# Out:
# ['FC(F)(F)F', 'c1nnon1', 'c1nnno1', 'FC=C(F)F', 'OC(=O)C#N', 'FC(F)C#N', 'N#CCC#N', 'OC(=O)C#C', 'FC(=C)C#N', 'OC(=O)C=O', 'NC(=O)C#N', 'FC=CC#N', 'ON=CC#N', 'FC(F)C#C', 'FC(F)C=O', 'c1cnon1', 'c1nnco1', 'c1conn1', 'c1nnn[nH]1', 'c1nn[nH]n1', 'c1ncon1', 'O=CCC#N', 'C#CCC#N', 'FC=CC=O', 'c1nc[nH]n1', 'ON=CC=O', 'NC(=N)C#N', 'OC(=O)CF', 'O=CNC=O', 'c1c[nH]nn1', 'CC#CC#N', 'C=NOC=O', 'FC=CC#C', 'N#CC1CO1', 'FC(=C)C#C', 'ON=CC#C', 'NC(=O)C#C', 'NC(=O)C=O', 'CC(=O)C#N', 'CC(F)(F)F', 'FC(=C)C=O', 'C1OC=NO1', 'FCC(F)F', 'c1cnoc1', 'c1cocn1', 'NN=CC#C', 'C#CCC#C', 'CC(=O)C=O', 'FCC=CF', 'c1ccoc1', 'NC(=O)CF', 'CC=C(F)F', 'OCC(O)=O', 'ONC=NO', 'c1c[nH]cn1', 'CC(F)=CF', 'FCC(F)=C', 'NC(=O)NO', 'ON=CCF', 'CC(=O)C#C', 'NC(=N)C#C', 'OC(=O)C=C', 'NC=CC#N', 'O=CCC#C', 'NC(=N)C=O', 'O=C1CCO1', 'O=C1COC1', 'OCC(F)F', 'FC1(F)CC1', 'O=CCC=O', 'CC(F)C#N', 'FC(F)C=C', 'c1cn[nH]c1', 'O=CC1CO1', 'C#CC1CO1', 'FC1CC1F', 'N#CC1CN1', 'C1OC=CO1', 'N=CNC=O', 'C=NNC=O', 'C=COC=O', 'CC#CC#C', 'C1C=NN=C1', 'CC#CC=O', 'FCCC#N', 'OC1CC1F', 'FCCC=O', 'OCCC#N', 'COCC#N', 'FC(=C)C=C', 'C=CCC#N', 'FCCC#C', 'O=C1CCN1', 'O=C1CNC1', 'NN=CCF', 'OCC=NO', 'FC1COC1', 'C=CNC=O', 'N=CNC=N', 'C=NNC=N', 'OCC=CF', 'CONC=O', 'c1cc[nH]c1', 'COC=CF', 'CC=CC#N', 'NC(=O)CO', 'NCC(F)F', 'CC(O)C#N', 'NC(=N)CF', 'CC(=O)CF', 'CC#CCF', 'NCC(O)=O', 'CC(F)C#C', 'FCC1CO1', 'C#CC1CN1', 'CN(O)C=O', 'N#CC1CC1', 'O=CC1CN1', 'CC(F)C=O', 'NC(=O)C=C', 'ON=CC=C', 'O=CN1CC1', 'OCC(F)=C', 'CC(=C)C#N', 'NN=CNO', 'COC(N)=O', 'COC=NO', 'NNC(N)=O', 'NC(=N)NO', 'FC=CC=C', 'NC=CC=O', 'CC(=O)NO', 'C1CC=NO1', 'C1CC=NN1', 'C1C=CC=C1', 'C=NN1CC1', 'COCC=O', 'C#CC1CC1', 'C1OCC=C1', 'CNNC=O', 'CONC=N', 'C1COCO1', 'C1CC=CO1', 'OCCC#C', 'CCOC=O', 'CNCC#N', 'COCC#C', 'C1CN=CN1', 'CN=CNO', 'N=CN1CC1', 'NNC=NN', 'COC=NN', 'CC=CC=O', 'OCCC=O', 'NN=CC=C', 'NN=CCO', 'NCC=NO', 'CC=NN=C', 'C=CCC=O', 'CC=CC#C', 'CC#CCO', 'C=CCC#C', 'CC#CC=C', 'C=COC=C', 'OCC1CO1', 'O=CC1CC1', 'C=CNC=N', 'C=CC1CO1', 'NCC=CF', 'FCC1CN1', 'FCCCF', 'COC(N)=N', 'NC1CC1F', 'O=C1CCC1', 'OC1COC1', 'FC1CNC1', 'CC(O)C=O', 'CN(N)C=O', 'CN(O)C=N', 'CC(=C)C#C', 'NC(=N)C=C', 'CC(=O)C=C', 'CC(=C)C=O', 'COC(C)=O', 'CNC(N)=O', 'NNC(N)=N', 'CC(=O)NN', 'CC(=N)NO', 'NCC(F)=C', 'CCC(O)=O', 'NCC(N)=O', 'NC(=N)CO', 'CC(=O)CO', 'OC1CC1O', 'CCC(F)F', 'CC(O)C#C', 'CC(C)(F)F', 'CC(F)CF', 'FCCC=C', 'CC(F)C=C', 'OCC1CN1', 'CC1(F)CC1', 'CN(C)C=O', 'CCC=CF', 'CN(N)C=N', 'C=CC1CN1', 'CC=CCF', 'CC(C)=NO', 'CC=C(C)F', 'CC(C)=CF', 'CC(O)CF', 'CN=CNN', 'COCCF', 'CON=CC', 'CNC(N)=N', 'CNC(C)=O', 'CC(=N)NN', 'CCC(F)=C', 'OCCCF', 'CCC(N)=O', 'NCC(N)=N', 'CC#CCN', 'CC(=C)CF', 'CC(N)C#C', 'FCC1CC1', 'NCC1CO1', 'FC1CCC1', 'OC1CNC1', 'CCC=NO', 'CC1CC1F', 'CCCC#N', 'CNCC#C', 'CCNC=O', 'CCON=C', 'CC(C)C#N', 'NCCC#C', 'CNNC=N', 'CC(F)CO', 'CNCC=O', 'C1NCC=C1', 'NC1COC1', 'NC1CC1O', 'CCNN=C', 'CC(F)CN', 'CCNC=N', 'OCCCO', 'NC1CC1N', 'CNCCF', 'CNC(C)=N', 'NC1CNC1', 'C1CCOC1', 'CCC#CC', 'NCCCF', 'CCC(C)=O', 'COCC=C', 'CC(=C)CO', 'C=CC1CC1', 'CC(C)C#C', 'CC1OC1C', 'OCC1CC1', 'C1CC=CC1', 'COC1CC1', 'CCC1CO1', 'NCC1CN1', 'CCC(N)=N', 'CC(N)CF', 'CNN=CC', 'CCOC=C', 'CC(O)C=C', 'CC1COC1', 'OC1CCC1', 'CCCC=O', 'CN(C)C=N', 'CC1(O)CC1', 'CC1CCO1', 'OCCC=C', 'CC=CCO', 'C=CCC=C', 'CC(C)C=O', 'CCC=NN', 'CC=CC=C', 'CC(C)=NN', 'CC1(C)CO1', 'CCCC#C', 'COC(C)=C', 'CN(C)N=C', 'COC=CC', 'CC1CC1O', 'COCCO', 'CC(=C)C=C', 'COCOC', 'CNC=NC', 'CC(O)CO', 'CCN1CC1', 'CC(C)(C)F', 'CC(N)C=C', 'CC(C)CF', 'CC(N)CO', 'CC(O)CN', 'CCC(C)F', 'C1CCNC1', 'NCCCO', 'CNC1CC1', 'NCCC=C', 'CCC1CN1', 'CNCC=C', 'CC1NC1C', 'CC1CC1N', 'COCCN', 'CN1CCC1', 'CC1CCN1', 'CC1CNC1', 'CC1CN1C', 'NC1CCC1', 'CNCCO', 'CC=CCN', 'CC1(N)CC1', 'CC(=C)CN', 'CCCCF', 'NCC1CC1', 'CC1(C)CN1', 'CCCOC', 'CC(N)CN', 'CCC(C)O', 'CNCCN', 'CCOCC', 'CC(C)CO', 'CCCC=C', 'CC(C)(C)O', 'CCCCO', 'COC(C)C', 'CCC=CC', 'NCCCN', 'CC=C(C)C', 'CC1(C)CC1', 'CCC(C)=C', 'CC1CCC1', 'CCC1CC1', 'CC(C)C=C', 'C1CCCC1', 'CC1CC1C', 'CCNCC', 'CCCCN', 'CCN(C)C', 'CNC(C)C', 'CC(C)CN', 'CC(C)(C)N', 'CCCNC', 'CCC(C)N', 'CCCCC', 'CCC(C)C', 'CC(C)(C)C']

# %%
from tqdm import tqdm 
from rdkit import Chem  
from rdkit.Chem import AllChem

from rdkit import RDLogger
lg = RDLogger.logger()
lg.setLevel(RDLogger.CRITICAL)

pbar = tqdm(sorted_smiles)

sorted_num_hs = []
for i, smile in enumerate(pbar): 
  atoms = [a for a in list(smile.upper()) if a == "C" or a == "N" or a == "O" or a == "F"]
  if len(atoms) != 5: continue 
  b = Chem.MolFromSmiles(smile)
  b = Chem.AddHs(b) 
  atoms = [atom.GetSymbol() for atom in b.GetAtoms()]
  hs =  len([a for a in atoms if a.upper() == "H"])
  if i % 10000 == 0: pbar.set_description(str(hs))
  sorted_num_hs.append(hs)
# Out:
# 0: 100%|██████████| 352/352 [00:00<00:00, 5035.95it/s]

# %%
import matplotlib.pyplot as plt 

plt.plot(num_hs)
plt.plot(sorted_num_hs)

# %%
sorted_num_hs = np.array(sorted_num_hs)
print(np.sum(sorted_num_hs[1:] != sorted_num_hs[:-1])) # check it only changes 20 times, once for each added hydrogen!
# Out:
# 12

# %%
import pandas as pd
df = pd.DataFrame(sorted_smiles[1:])
df.to_csv('gdb11_size05_sorted.csv', index=False, header=False)

# %%
# !less gdb11_size09_sorted.csv
# Out:
# 07=
# [O-][N+](=O)c1nnon1
# N#CC#Cc1nnon1
# Fc1nc(=O)nc(F)o1
# Fc1onc2onnc12
# N#Cc1noc(n1)C#N
# Fc1nc2onnc2o1
# O=c1onc2onnn12
# Fc1onnc(=O)c1F
# Fc1onc2OC(=O)c12
# FC(C#N)=C(C#N)C#N
# Fc1nc(=O)c(F)no1
# [O-][N+](=O)c1onnc1F
# [O-][N+](=O)c1nnc(F)o1
# O=C1OC(=O)C(=O)C1=O
# FC(F)(F)c1nnno1
# Fc1nc(=O)oc(=O)o1
# N#CC(C#N)(C#N)C#N
# Fc1nc(oc1F)C#N
# Fc1nonc(F)c1=O
# N#Cc1nnc(o1)C#N
# O=c1nnnnc(=O)o1
# O=C(C#N)c1nnno1
# :11_size09_sorted.csv

# %%
# one of the molecules had only 8 atoms, remove those check thi 
# they basically included hydrogens in the SMILEs string. 
# we remove theese. 
num_atoms = []
for smile in tqdm(smiles):
  atoms = [a for a in list(smile.upper()) if a == "C" or a == "N" or a == "O" or a == "F"]

  if len(atoms) != 9: print(smile, list(smile), atoms)
  num_atoms.append(len(atoms))
# Out:
#  95%|█████████▍| 420551/444314 [00:01<00:00, 439932.23it/s]
# [O-][N+](=O)c1ccc[nH]1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'c', 'c', '[', 'n', 'H', ']', '1'] ['O', 'N', 'O', 'C', 'C', 'C', 'C', 'N']
# [O-][N+](=O)c1c[nH]cn1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', '[', 'n', 'H', ']', 'c', 'n', '1'] ['O', 'N', 'O', 'C', 'C', 'N', 'C', 'N']
# [O-][N+](=O)c1cc[nH]n1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'c', '[', 'n', 'H', ']', 'n', '1'] ['O', 'N', 'O', 'C', 'C', 'C', 'N', 'N']
# [O-][N+](=O)c1cnn[nH]1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'n', 'n', '[', 'n', 'H', ']', '1'] ['O', 'N', 'O', 'C', 'C', 'N', 'N', 'N']
# [O-][N+](=O)c1ncc[nH]1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'c', 'c', '[', 'n', 'H', ']', '1'] ['O', 'N', 'O', 'C', 'N', 'C', 'C', 'N']
# [O-][N+](=O)c1nc[nH]n1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'c', '[', 'n', 'H', ']', 'n', '1'] ['O', 'N', 'O', 'C', 'N', 'C', 'N', 'N']
# [O-][N+](=O)c1ncn[nH]1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'c', 'n', '[', 'n', 'H', ']', '1'] ['O', 'N', 'O', 'C', 'N', 'C', 'N', 'N']
# [O-][N+](=O)c1nnn[nH]1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'n', 'n', '[', 'n', 'H', ']', '1'] ['O', 'N', 'O', 'C', 'N', 'N', 'N', 'N']
# [O-][N+](=O)c1ccco1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'c', 'c', 'o', '1'] ['O', 'N', 'O', 'C', 'C', 'C', 'C', 'O']
# [O-][N+](=O)c1cnco1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'n', 'c', 'o', '1'] ['O', 'N', 'O', 'C', 'C', 'N', 'C', 'O']
# [O-][N+](=O)c1ccno1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'c', 'n', 'o', '1'] ['O', 'N', 'O', 'C', 'C', 'C', 'N', 'O']
# [O-][N+](=O)c1cnno1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'n', 'n', 'o', '1'] ['O', 'N', 'O', 'C', 'C', 'N', 'N', 'O']
# [O-][N+](=O)c1ncco1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'c', 'c', 'o', '1'] ['O', 'N', 'O', 'C', 'N', 'C', 'C', 'O']
# [O-][N+](=O)c1nnco1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'n', 'c', 'o', '1'] ['O', 'N', 'O', 'C', 'N', 'N', 'C', 'O']
# [O-][N+](=O)c1ncno1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'c', 'n', 'o', '1'] ['O', 'N', 'O', 'C', 'N', 'C', 'N', 'O']
# [O-][N+](=O)c1nnno1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'n', 'n', 'o', '1'] ['O', 'N', 'O', 'C', 'N', 'N', 'N', 'O']
# [O-][N+](=O)c1cc[nH]c1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'c', '[', 'n', 'H', ']', 'c', '1'] ['O', 'N', 'O', 'C', 'C', 'C', 'N', 'C']
# [O-][N+](=O)c1ccoc1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'c', 'o', 'c', '1'] ['O', 'N', 'O', 'C', 'C', 'C', 'O', 'C']
# [O-][N+](=O)c1cn[nH]c1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'n', '[', 'n', 'H', ']', 'c', '1'] ['O', 'N', 'O', 'C', 'C', 'N', 'N', 'C']
# [O-][N+](=O)c1cnoc1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'n', 'o', 'c', '1'] ['O', 'N', 'O', 'C', 'C', 'N', 'O', 'C']
# [O-][N+](=O)c1ccon1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'c', 'o', 'n', '1'] ['O', 'N', 'O', 'C', 'C', 'C', 'O', 'N']
# [O-][N+](=O)c1c[nH]nn1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', '[', 'n', 'H', ']', 'n', 'n', '1'] ['O', 'N', 'O', 'C', 'C', 'N', 'N', 'N']
# [O-][N+](=O)c1cnon1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'n', 'o', 'n', '1'] ['O', 'N', 'O', 'C', 'C', 'N', 'O', 'N']
# [O-][N+](=O)c1cocn1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'o', 'c', 'n', '1'] ['O', 'N', 'O', 'C', 'C', 'O', 'C', 'N']
# [O-][N+](=O)c1conn1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'c', 'o', 'n', 'n', '1'] ['O', 'N', 'O', 'C', 'C', 'O', 'N', 'N']
# [O-][N+](=O)c1ncon1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'c', 'o', 'n', '1'] ['O', 'N', 'O', 'C', 'N', 'C', 'O', 'N']
# [O-][N+](=O)c1nn[nH]n1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'n', '[', 'n', 'H', ']', 'n', '1'] ['O', 'N', 'O', 'C', 'N', 'N', 'N', 'N']
# [O-][N+](=O)c1nnon1 ['[', 'O', '-', ']', '[', 'N', '+', ']', '(', '=', 'O', ')', 'c', '1', 'n', 'n', 'o', 'n', '1'] ['O', 'N', 'O', 'C', 'N', 'N', 'O', 'N']
# 100%|██████████| 444314/444314 [00:01<00:00, 419157.95it/s]
#  [] []

# %%
# one of the molecules had only 8 atoms, remove those check thi 
# they basically included hydrogens in the SMILEs string. 
# we remove theese. 
num_atoms = []
for smile in tqdm(sorted_smiles):
  atoms = [a for a in list(smile.upper()) if a == "C" or a == "N" or a == "O" or a == "F"]

  if len(atoms) != 9: print(smile, list(smile), atoms)
  num_atoms.append(len(atoms))
# Out:
# 100%|██████████| 1024/1024 [00:00<00:00, 316038.80it/s]

# %%
plt.plot(num_atoms)

# %%
addhs = []
addexplicit = []

for i, smile in enumerate(pbar): 
  atoms = [a for a in list(smile.upper()) if a == "C" or a == "N" or a == "O" or a == "F"]
  if len(atoms) != 5: continue 
  b = Chem.MolFromSmiles(smile)
  atoms = [atom.GetSymbol() for atom in Chem.AddHs(b, explicitOnly=True).GetAtoms()] # this only adds 1! 
  atoms = [atom.GetSymbol() for atom in Chem.AddHs(b, explicitOnly=True).GetAtoms()] # this only adds 1! 
  hs =  len([a for a in atoms if a.upper() == "H"])
  addhs.append(hs)

plt.plot(addhs)
